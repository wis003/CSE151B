# %% [markdown]
# ## Install the package dependencies before running this notebook

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, os.path 
import numpy 
import pickle
from glob import glob

"""
    number of trajectories in each city
    # austin --  train: 43041 test: 6325 
    # miami -- train: 55029 test:7971
    # pittsburgh -- train: 43544 test: 6361
    # dearborn -- train: 24465 test: 3671
    # washington-dc -- train: 25744 test: 3829
    # palo-alto -- train:  11993 test:1686

    trajectories sampled at 10HZ rate, input 5 seconds, output 6 seconds
    
"""
# Out:
# '\n    number of trajectories in each city\n    # austin --  train: 43041 test: 6325 \n    # miami -- train: 55029 test:7971\n    # pittsburgh -- train: 43544 test: 6361\n    # dearborn -- train: 24465 test: 3671\n    # washington-dc -- train: 25744 test: 3829\n    # palo-alto -- train:  11993 test:1686\n\n    trajectories sampled at 10HZ rate, input 5 seconds, output 6 seconds\n    \n'

# %% [markdown]
# ## Create a Torch.Dataset class for the training dataset

# %%
from glob import glob
import pickle
import numpy as np

ROOT_PATH = "./Data/"

cities = ["austin", "miami", "pittsburgh", "dearborn", "washington-dc", "palo-alto"]
splits = ["train", "test"]

def get_city_trajectories(city="palo-alto", split="train", normalized=False):

    outputs = None
    
    if split=="train":
        f_in = ROOT_PATH + split + "/" + city + "_inputs"
        inputs = np.asarray(pickle.load(open(f_in, "rb")))
#         n = len(inputs)
#         inputs = np.asarray(inputs)[:int(n * 0.8)]
        
        f_out = ROOT_PATH + split + "/" + city + "_outputs"
        outputs = np.asarray(pickle.load(open(f_out, "rb")))
#         outputs = np.asarray(outputs)[:int(n * 0.8)]
        
    elif split == 'val':
        f_in = ROOT_PATH + 'train' + "/" + city + "_inputs"
        inputs = pickle.load(open(f_in, "rb"))
        n = len(inputs)
        inputs = np.asarray(inputs)[int(n * 0.8):]
        
        f_out = ROOT_PATH + 'train' + "/" + city + "_outputs"
        outputs = pickle.load(open(f_out, "rb"))
        outputs = np.asarray(outputs)[int(n * 0.8):]
    
    else:
        f_in = ROOT_PATH + split + "/" + city + "_inputs"
        inputs = pickle.load(open(f_in, "rb"))
        n = len(inputs)
        inputs = np.asarray(inputs)

    return inputs, outputs

class ArgoverseDataset(Dataset):
    """Dataset class for Argoverse"""
    def __init__(self, city: str, split:str, transform=None):
        super(ArgoverseDataset, self).__init__()
        self.transform = transform

        self.inputs, self.outputs = get_city_trajectories(city=city, split=split, normalized=False)

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):

        data = (self.inputs[idx], self.outputs[idx])
            
        if self.transform:
            data = self.transform(data)

        return data

# %% [markdown]
# ## Create a DataLoader class for training

# %%
from torch import nn, optim

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class MLP(nn.Module):

    def __init__(self):
        super().__init__()
        
        self.encoder = nn.Sequential(
            nn.Linear(100, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 32)
        )
        
        self.decoder = nn.Sequential(
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, 120),
            nn.ReLU(),
            nn.Linear(120, 120)
        )
        
    def forward(self, x):
        x = x.reshape(-1, 100).float()
        x = self.encoder(x)
        x = self.decoder(x)
        x = x.reshape(-1, 60, 2)
        return x
    
class LR(nn.Module):

    def __init__(self):
        super().__init__()
        
        self.linear = nn.Linear(50, 1)
        
    def forward(self, x):
        return self.linear(x.float())

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# pred = MLP()
# pred.to(device)
# opt = optim.Adam(pred.parameters(), lr=1e-3)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
lr_X = LR()
lr_X.to(device)
opt_X = optim.Adam(lr_X.parameters(), lr=1e-3)

lr_Y = LR()
lr_Y.to(device)
opt_Y = optim.Adam(lr_Y.parameters(), lr=1e-3)

# %% [markdown]
# ## Training

# %%
import time
from tqdm.notebook import tqdm

start = time.time()
loss_over_time = []

for epoch in range(30):
    total_loss = 0
    for city in cities:
        train_dataset = ArgoverseDataset(city = city, split = 'train')
        
        for i in tqdm(range(len(train_dataset.inputs))):
            new_i = np.zeros((60, 50, 2))
            new_o = np.zeros((60, 2))
            total_dataset = np.hstack((np.array([train_dataset.inputs[i]]), np.array([train_dataset.outputs[i]])))
            
            for j in range(60):
                new_i[j,:,:] = total_dataset[0,j:j+50,:]
                new_o[j,:] = total_dataset[0,j+50,:]
                
            i_X = torch.from_numpy(new_i[:,:,0]).to(device)
            o_X = torch.from_numpy(new_o[:,0]).to(device)
            
            i_Y = torch.from_numpy(new_i[:,:,1]).to(device)            
            o_Y = torch.from_numpy(new_o[:,1]).to(device)
            
            preds_X = lr_X(i_X)
            loss_X = ((preds_X - o_X) ** 2).sum()
            
            preds_Y = lr_Y(i_Y)
            loss_Y = ((preds_Y - o_Y) ** 2).sum()
            
            opt_X.zero_grad()
            loss_X.backward()
            opt_X.step()
            
            opt_Y.zero_grad()
            loss_Y.backward()
            opt_Y.step()

            total_loss += loss
            print(loss_X)

    end = time.time()
    loss_over_time.append(total_loss)
    print('Time elapsed: {}'.format((end - start) / 60))
    print('epoch {} loss: {}'.format(epoch, total_loss / 24457920))
# Out:
#   0%|          | 0/43041 [00:00<?, ?it/s]
# tensor(1548.5420, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# tensor(156894.4933, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(257484.9959, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(530953.6770, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2094624.5024, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(401708.1300, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1485433.9799, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(293251.1191, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(287336.3387, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(243109.5570, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2267686.0670, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(88835.6412, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(3329455.5647, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1427576.1206, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(5262893.8657, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1040580.9861, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1428355.4483, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2840829.4352, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(262475.9886, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1729493.7118, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(5944.0743, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# tensor(35648.7083, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(3687376.4955, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(6437196.7929, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1774476.5337, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(3904297.1978, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(28036.6804, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(5459070.1819, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(4600247.1410, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(52894.9010, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1964355.3819, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1082245.1683, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(90018.1915, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(90969.8392, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(9856887.6880, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(831445.9201, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(995613.4092, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2441759.4405, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(346375.1634, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(42479.0007, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(59092.0154, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1257249.6179, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2309351.8579, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(582885.3139, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(8718116.3481, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(224643.4765, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(368282.3225, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(495056.1097, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2128607.1463, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(730247.8850, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(98270.3982, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(4835.3568, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# tensor(3564757.5271, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1144119.1643, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(502296.4540, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(4313307.5188, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2414907.5176, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1406736.8939, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(537866.1401, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(754556.9051, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(499644.4067, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(54574.4819, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1666035.5785, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(22249.7702, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1766669.1318, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(508205.3346, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(19446.8208, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(3496385.8282, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(910978.7130, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(8375504.5524, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1817837.8495, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(59255.4346, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(3680119.1021, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(3915162.9308, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1456819.7626, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2757842.8967, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2922877.1708, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(171877.0216, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(509178.7852, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(4186813.5070, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(785896.5763, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(16745119.7692, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(790197.8505, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(116226.8564, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(27733.2191, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2790080.2470, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(12986.0044, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(8911942.5045, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(747217.6135, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2806169.2517, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(4772191.5662, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(858612.6513, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(633195.7006, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(7393463.6764, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(7650.0135, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# tensor(155333.9545, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(464404.0536, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2952.1687, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# tensor(1604797.1483, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(8126.2176, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# tensor(355139.6738, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(387635.6241, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(210686.0865, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(4595616.9269, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(262050.3942, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(840831.4419, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(39210.3902, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(6425944.5030, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1122229.0239, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(750.5859, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# tensor(2579770.3287, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(5335723.1634, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(136240.0419, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2737155.7452, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(6221315.6391, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1237010.9072, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(576099.2123, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1732801.4635, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(239048.5860, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(358605.8744, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(139753.6997, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(673672.8055, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(847979.1239, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(97768.1466, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(3787366.0589, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1460574.2298, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(1083932.3549, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(2097839.2029, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(97859.5259, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(601143.2935, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(3582707.1954, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# tensor(
lib/python3.9/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# /opt/conda/lib/python3.9/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145         retain_graph = create_graph
#     146
# --> 147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# ## Validation

# %%
# val_dataset = ArgoverseDataset(city = 'austin', split = 'val')
# val_loader = DataLoader(val_dataset, batch_size=batch_sz)

# val_loss = 0
# for i_batch, sample_batch in enumerate(val_loader):
#     i, o = sample_batch
#     inp, out = i.to(device), o.to(device)
#     preds = pred(inp)
#     loss = ((preds - out) ** 2).sum()

#     val_loss += loss.item()
# print('loss: {}'.format(val_loss / len(val_dataset)))

# %% [markdown]
# ## Testing

# %%
import pandas as pd

df = pd.read_csv(ROOT_PATH + 'submission.csv')
int_col = df.select_dtypes(include=['int'])
for col in int_col.columns.values:
    df[col] = df[col].astype('float32')
row = 0

for city in cities:
    print(city)
    test_dataset = ArgoverseDataset(city = city, split = 'test')

    for i in range(len(test_dataset.inputs)):
        data = torch.from_numpy(test_dataset.inputs[i]).to(device)
        preds = pred(data)
        df.iloc[row, 1:121] = preds.cpu().detach().numpy().ravel()
        row += 1
        
df.to_csv(ROOT_PATH + 'submission.csv', index=False)
# Out:
# austin
# miami
# pittsburgh
# dearborn
# washington-dc
# palo-alto

# %% [markdown]
# ## Sample a batch of data and visualize

# %%
import matplotlib.pyplot as plt

check = [39, 984, 3075, 6132]

check_dataset = ArgoverseDataset(city = 'austin', split = 'train')
for i in range(len(check_dataset.inputs)):
    if i in check:
        data = torch.from_numpy(check_dataset.inputs[i]).to(device)
        out = check_dataset.outputs[i]
        preds = pred(data).cpu().detach().numpy()
        
        loss = ((preds - out) ** 2).sum()
        print(i)
        print(loss)
        print(preds.shape)
        print(out.shape)
        
        plt.figure(figsize=(4, 4))
        plt.scatter(preds[0, :, 0], preds[0, :, 1], label='prediction')
        plt.scatter(out[:, 0], out[:, 1], label='gt_out')
        plt.scatter(check_dataset.inputs[i][:, 0], check_dataset.inputs[i][:, 1], label='gt_in')
        plt.xlabel('X coordinates')
        plt.ylabel('Y coordinates')
        plt.title(i, fontweight ="bold")
        plt.legend()
        plt.show()
# Out:
# 39
# 413896.1825946247
# (1, 60, 2)
# (60, 2)
# 984
# 28327.25811416954
# (1, 60, 2)
# (60, 2)
# 3075
# 129714.85896842205
# (1, 60, 2)
# (60, 2)
# 6132
# 48474.49989137119
# (1, 60, 2)
# (60, 2)

# %%
import matplotlib.pyplot as plt

loss_over_time = [30195.15069716215, 22749.236565336407, 16024.36511451192, 12384.892262974807,
                  9036.392011609767, 8282.051759443071, 8533.021177586535, 7909.96047883325,
                  8554.438741715541, 7525.633394016485, 8538.137926249668, 9476.19942715907,
                  8019.01293861122, 5810.399060154654, 6533.316923337074, 6372.714955296739,
                  5077.422979607126, 9078.002393526049, 5892.201587279284, 6475.244141981521,
                  6096.543173084354, 5161.303367523278, 4683.183947240653, 4673.732035488378,
                  4551.751793117595, 4578.098822617955, 5958.7015263762905, 6732.379079572472,
                  4741.237799342999, 7021.2966974634, 5253.814058198382, 6063.218152811302,
                  9290.063951731241, 4383.815530866721, 6919.929489778211, 4800.752952358283,
                  4549.801874309958, 3949.6386289254565, 4551.014492151343, 5743.232055564923]

plt.plot(loss_over_time)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('training loss over time')
plt.savefig('Data/documentation/loss_over_time.png')
plt.show()

# %%
# torch.save(pred, './Data/saved_models/linear_model_no_dropout')
